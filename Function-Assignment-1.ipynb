# %%
# Create a function and list out the items in the list 

SubfieldsInAI = ('Sub-fields in AI are:', 
                 'Machine Learning',
                 'Neural Networks', 
                 'Vision',
                 'Robotics', 
                 'Speech Processing', 
                 'Natural Language Processing')


    
def Subfields():
    return "\n".join(SubfieldsInAI)

print(Subfields())
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
#Create Function
num = int(input("Enter a number:"))

def OddEven():
    if(num%2==0):
        print("The number is even")
        check = "Even number"
    else:
        print("The number is odd")
        check = "Odd number"

    return check
# Out:
# Enter a number: 4

# %%
OddEven()
# Out:
# The number is even
# 'Even number'

# %%
check = OddEven()
# Out:
# The number is even

# %%
print(check)
# Out:
# Even number

# %%
Gender = (input("Your Gender:"))
Age = int(input("Your Age:"))

def eligible():
    
    if Gender.lower()=="male" and Age < 27:
        print("NOT ELIGIBLE")
    else:
        print("ELIGIBLE")
        
eligible()
# Out:
# Your Gender: male
# Your Age: 18
# NOT ELIGIBLE

# %%
def add(Subject1, Subject2, Subject3, Subject4, Subject5):
    total = Subject1 + Subject2 + Subject3 + Subject4 + Subject5
    return total

def percentage(Subject1, Subject2, Subject3, Subject4, Subject5):
    total = Subject1 + Subject2 + Subject3 + Subject4 + Subject5
    return (total / 500) * 100
    
print("subject1=23")
print("subject1=45")
print("subject1=34")
print("subject1=23")
print("subject1=23")

result = add(23, 45, 34, 23, 23)
print("Total:", result)

result1 = percentage(23, 45, 34, 23, 23)
print("Percentage:", result1)
# Out:
# subject1=23
# subject1=45
# subject1=34
# subject1=23
# subject1=23
# Total: 148
# Percentage: 29.599999999999998

# %%
def triangle(Height,Breadth):
    area = (Height*Breadth)/2
    return area
    
def perimeter(Height1,Height2,Breadth):
    return Height1+Height2+Breadth

print("Height:3")
print("Breadth:4")
print("Area formula: (Height*Breadth)/2")


result = triangle(3,4)
print("Area of Triangle:",result)

print("Height1:3")
print("Height2:4")
print("Breadth:45")

print("Perimeter formula: Height1+Height2+Breadth")

result1 = perimeter(3,4,45) 
print("Perimeter of Triangle:",result1)
# Out:
# Height:3
# Breadth:4
# Area formula: (Height*Breadth)/2
# Area of Triangle: 6.0
# Height1:3
# Height2:4
# Breadth:45
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 52

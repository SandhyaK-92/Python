# %%
from ClassAssignment1 import multipleFunctions

# %%
multipleFunctions.OddEven()
# Out:
# Enter a number: 67
# 67 is Odd number

# %%
multipleFunctions.eligible()
# Out:
# Your Gender: Male
# Your Age: 18
# NOT ELIGIBLE
# 'NOT ELIGIBLE'

# %%
multipleFunctions.add(98,87,95,95,93)
# Out:
# 468

# %%
multipleFunctions.percentage(98,87,95,95,93)
# Out:
# 93.60000000000001

# %%
multipleFunctions.triangle(32,34)
# Out:
# 544.0

# %%
multipleFunctions.perimeter(2,4,4)
# Out:
# 10
